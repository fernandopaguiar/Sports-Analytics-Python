# %% [markdown]
# <a href="https://colab.research.google.com/github/fernandopaguiar/fernandopaguiar/blob/main/SoccerLabs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import locale

# %%
a8 = pd.read_csv('/content/AVALIACAO_FISICA_A8 - Página1.csv')
a8.head()
# Out:
#    ID_AVALIACAO                    NOME_ATLETA DATA_NASCIMENTO DATA_AVALIACAO  \
# 0             1  FABIO AUGUSTO PEREIRA QUIRINO      23/01/2007     10/01/2022
# 1             2                 PEDRO BERNARDO      30/05/2008     10/01/2022
# 2             3         MATHEUS RAMOS DE SOUSA      27/06/2007     10/01/2022
# 3             4      ARTHUR ALBUQUERQUE SANTOS      14/01/2007     10/01/2022
# 4             5         GUILHERME DORO BOTELHO      13/07/2007     10/01/2022
#
#   ESTATURA   PESO    IMC  PEITO  OMBRO  CINTURA  ...  BRACO_E  IMPULSIVIDADE  \
# 0     1,75  51,05  16,67     77    100      NaN  ...     23.0             29
# 1     1,56   37,7  15,49     74     90      NaN  ...     20.0             30
# 2      1,7  61,75  21,37     86    106      NaN  ...     26.0             30
# 3     1,69  94,85  33,21    106    119      NaN  ...     32.0             30
# 4     1,56  44,65  18,35     74     90      NaN  ...     23.0             29
#
# ...

# %%
a8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID_AVALIACAO     53 non-null     int64
#  1   NOME_ATLETA      53 non-null     object
#  2   DATA_NASCIMENTO  53 non-null     object
#  3   DATA_AVALIACAO   53 non-null     object
#  4   ESTATURA         53 non-null     object
#  5   PESO             53 non-null     object
#  6   IMC              53 non-null     object
#  7   PEITO            53 non-null     int64
#  8   OMBRO            53 non-null     int64
#  9   CINTURA          41 non-null     float64
#  10  QUADRIL          53 non-null     int64
#  11  COXA_D           53 non-null     int64
#  12  COXA_E           53 non-null     int64
#  13  PERNA_D          53 non-null     int64
#  14  PERNA_E          53 non-null     int64
#  15  BRACO_D          52 non-null     float64
#  16  BRACO_E          52 non-null     float64
# ...

# %%
type(a8)
# Out:
# pandas.core.frame.DataFrame

# %%
a8.shape
# Out:
# (53, 26)

# %%
a8.columns = ["Id", "nome", "data_nascimento", "data_avaliacao", "estatura", "peso", "imc", "peito", "ombro", "cintura",
              "quadril", "coxa_d", "coxa_e", "perna_d", "perna_e", "braco_d", "braco_e", "impulsividade", "flexibilidade",
              "vo2max", "teste_t", "sprint_20m", "adutor_d", "adutor_e", "posterior_d", "posterior_e"]

# %%
a8.head()
# Out:
#    Id                           nome data_nascimento data_avaliacao estatura  \
# 0   1  FABIO AUGUSTO PEREIRA QUIRINO      23/01/2007     10/01/2022     1,75
# 1   2                 PEDRO BERNARDO      30/05/2008     10/01/2022     1,56
# 2   3         MATHEUS RAMOS DE SOUSA      27/06/2007     10/01/2022      1,7
# 3   4      ARTHUR ALBUQUERQUE SANTOS      14/01/2007     10/01/2022     1,69
# 4   5         GUILHERME DORO BOTELHO      13/07/2007     10/01/2022     1,56
#
#     peso    imc  peito  ombro  cintura  ...  braco_e  impulsividade  \
# 0  51,05  16,67     77    100      NaN  ...     23.0             29
# 1   37,7  15,49     74     90      NaN  ...     20.0             30
# 2  61,75  21,37     86    106      NaN  ...     26.0             30
# 3  94,85  33,21    106    119      NaN  ...     32.0             30
# 4  44,65  18,35     74     90      NaN  ...     23.0             29
#
#    flexibilidade  vo2max  teste_t  sprint_20m  adutor_d  adutor_e  \
# ...

# %%
a8.dtypes
# Out:
# Id                   int64
# nome                object
# data_nascimento     object
# data_avaliacao      object
# estatura            object
# peso                object
# imc                 object
# peito                int64
# ombro                int64
# cintura            float64
# quadril              int64
# coxa_d               int64
# coxa_e               int64
# perna_d              int64
# perna_e              int64
# braco_d            float64
# braco_e            float64
# impulsividade        int64
# flexibilidade        int64
# vo2max              object
# teste_t             object
# sprint_20m          object
# adutor_d           float64
# adutor_e           float64
# posterior_d          int64
# posterior_e          int64
# dtype: object

# %%
a8['imc'] = a8['imc'].str.replace(',','.').astype(float)

# %%
a8['peso'] = a8['peso'].str.replace(',','.').astype(float)

# %%
a8['estatura'] = a8['estatura'].str.replace(',','.').astype(float)

# %%
a8['teste_t'] = a8['teste_t'].str.replace(',','.').astype(float)

# %%
a8['vo2max'] = a8['vo2max'].str.replace(',','.').astype(float)

# %%
a8['sprint_20m'] = a8['sprint_20m'].str.replace(',','.').astype(float)

# %%
a8['data_nascimento'] = pd.to_datetime(a8['data_nascimento'])
a8['data_nascimento']
# Out:
# 0    2007-01-23
# 1    2008-05-30
# 2    2007-06-27
# 3    2007-01-14
# 4    2007-07-13
# 5    2007-03-19
# 6    2008-07-03
# 7    2007-08-01
# 8    2007-08-28
# 9    2008-03-25
# 10   2007-01-21
# 11   2005-10-06
# 12   2005-07-15
# 13   2005-11-03
# 14   2005-12-13
# 15   2005-07-15
# 16   2005-04-12
# 17   2006-09-17
# 18   2005-06-19
# 19   2005-10-18
# 20   2006-04-19
# 21   2005-03-03
# 22   2005-11-17
# 23   2003-08-09
# 24   2002-10-24
# 25   2004-06-13
# 26   2002-10-30
# 27   2004-04-22
# 28   2004-10-11
# 29   2003-02-07
# 30   2003-02-07
# 31   2003-09-04
# 32   2002-07-31
# 33   2002-02-02
# 34   2004-03-15
# 35   2004-07-05
# 36   2002-06-12
# 37   2004-12-19
# 38   2002-02-22
# 39   2003-10-12
# 40   2003-03-11
# 41   2002-01-01
# 42   2000-11-16
# 43   2000-10-31
# 44   1999-03-11
# 45   2001-03-08
# 46   2000-06-21
# 47   1999-06-02
# 48   1998-04-08
# 49   1999-07-24
# 50   1996-01-04
# 51   1994-12-09
# 52   2000-11-28
# ...

# %%
a8['data_avaliacao'] = pd.to_datetime(a8['data_avaliacao'])
a8['data_avaliacao']
# Out:
# 0    2022-10-01
# 1    2022-10-01
# 2    2022-10-01
# 3    2022-10-01
# 4    2022-10-01
# 5    2022-10-01
# 6    2022-10-01
# 7    2022-10-01
# 8    2022-10-01
# 9    2022-10-01
# 10   2022-10-01
# 11   2022-10-01
# 12   2022-10-01
# 13   2022-10-01
# 14   2022-10-01
# 15   2022-10-01
# 16   2022-10-01
# 17   2022-10-01
# 18   2022-10-01
# 19   2022-10-01
# 20   2022-10-01
# 21   2022-10-01
# 22   2022-10-01
# 23   2022-10-01
# 24   2022-10-01
# 25   2022-10-01
# 26   2022-10-01
# 27   2022-10-01
# 28   2022-10-01
# 29   2022-10-01
# 30   2022-10-01
# 31   2022-10-01
# 32   2022-10-01
# 33   2022-10-01
# 34   2022-10-01
# 35   2022-10-01
# 36   2022-10-01
# 37   2022-10-01
# 38   2022-10-01
# 39   2022-10-01
# 40   2022-10-01
# 41   2022-10-01
# 42   2022-10-01
# 43   2022-10-01
# 44   2022-10-01
# 45   2022-10-01
# 46   2022-10-01
# 47   2022-10-01
# 48   2022-10-01
# 49   2022-10-01
# 50   2022-10-01
# 51   2022-10-01
# 52   2022-10-01
# Name: data_avaliacao, dtype: datetime64[ns]

# %%
a8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Id               53 non-null     int64
#  1   nome             53 non-null     object
#  2   data_nascimento  53 non-null     datetime64[ns]
#  3   data_avaliacao   53 non-null     datetime64[ns]
#  4   estatura         53 non-null     float64
#  5   peso             53 non-null     float64
#  6   imc              53 non-null     float64
#  7   peito            53 non-null     int64
#  8   ombro            53 non-null     int64
#  9   cintura          41 non-null     float64
#  10  quadril          53 non-null     int64
#  11  coxa_d           53 non-null     int64
#  12  coxa_e           53 non-null     int64
#  13  perna_d          53 non-null     int64
#  14  perna_e          53 non-null     int64
#  15  braco_d          52 non-null     float64
# ...

# %%
data_avaliacao = a8['data_avaliacao'].drop_duplicates()
data_avaliacao
# Out:
# 0   2022-10-01
# Name: data_avaliacao, dtype: datetime64[ns]

# %%
a8.describe()
# Out:
#               Id   estatura       peso        imc       peito       ombro  \
# count  53.000000  53.000000  53.000000  53.000000   53.000000   53.000000
# mean   27.000000   1.741321  67.211321  22.043774   88.924528  107.981132
# std    15.443445   0.076386  11.885267   2.956003    7.439109    7.642217
# min     1.000000   1.560000  37.700000  15.490000   74.000000   90.000000
# 25%    14.000000   1.690000  61.750000  20.320000   84.000000  102.000000
# 50%    27.000000   1.740000  65.350000  21.750000   89.000000  109.000000
# 75%    40.000000   1.800000  73.900000  23.470000   93.000000  112.000000
# max    53.000000   1.920000  94.850000  33.210000  106.000000  124.000000
#
#          cintura     quadril     coxa_d     coxa_e  ...    braco_e  \
# count  41.000000   53.000000  53.000000  53.000000  ...  52.000000
# mean   77.243902   94.490566  52.018868  50.905660  ...  26.769231
# std     6.891228    8.061358   4.338958   5.805383  ...   2.748371
# ...

# %%
media = a8.mean()
media
# Out:
# <ipython-input-20-aabae0b10a99>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   media = a8.mean()
# <ipython-input-20-aabae0b10a99>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   media = a8.mean()
# Id                27.000000
# estatura           1.741321
# peso              67.211321
# imc               22.043774
# peito             88.924528
# ombro            107.981132
# cintura           77.243902
# quadril           94.490566
# coxa_d            52.018868
# coxa_e            50.905660
# perna_d           36.603774
# perna_e           36.528302
# braco_d           26.807692
# braco_e           26.769231
# impulsividade     29.188679
# flexibilidade      9.716981
# vo2max            20.067568
# ...

# %%
minimo = a8.min()
minimo
# Out:
# Id                                         1
# nome               ADRIEL FERREIRA VIRGOLINO
# data_nascimento          1994-12-09 00:00:00
# data_avaliacao           2022-10-01 00:00:00
# estatura                                1.56
# peso                                    37.7
# imc                                    15.49
# peito                                     74
# ombro                                     90
# cintura                                 56.0
# quadril                                   70
# coxa_d                                    39
# coxa_e                                    20
# perna_d                                   30
# perna_e                                   28
# braco_d                                 21.0
# braco_e                                 20.0
# impulsividade                             27
# flexibilidade                              0
# vo2max                                  15.2
# teste_t                                 9.47
# ...

# %%
mediana = a8.median()
mediana
# Out:
# <ipython-input-22-a8ba8a8c8660>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   mediana = a8.median()
# <ipython-input-22-a8ba8a8c8660>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   mediana = a8.median()
# Id                27.00
# estatura           1.74
# peso              65.35
# imc               21.75
# peito             89.00
# ombro            109.00
# cintura           76.00
# quadril           95.00
# coxa_d            51.00
# coxa_e            51.00
# perna_d           36.00
# perna_e           36.00
# braco_d           26.00
# braco_e           26.00
# impulsividade     30.00
# flexibilidade     10.00
# vo2max            20.40
# teste_t           10.12
# sprint_20m         3.28
# ...

# %%
maximo = a8.max()
maximo
# Out:
# Id                                    53
# nome               VITOR COSTA LIMA SENA
# data_nascimento      2008-07-03 00:00:00
# data_avaliacao       2022-10-01 00:00:00
# estatura                            1.92
# peso                               94.85
# imc                                33.21
# peito                                106
# ombro                                124
# cintura                             97.0
# quadril                              116
# coxa_d                                61
# coxa_e                                60
# perna_d                               56
# perna_e                               56
# braco_d                             34.0
# braco_e                             35.0
# impulsividade                         30
# flexibilidade                         26
# vo2max                              23.7
# teste_t                            11.91
# sprint_20m                          3.81
# adutor_d                           157.0
# ...

# %%
desvio_padrao = a8.std()
desvio_padrao
# Out:
# <ipython-input-24-d4217eb18f2d>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   desvio_padrao = a8.std()
# Id                                    15.443445
# data_nascimento    1134 days 07:58:41.562561520
# data_avaliacao                  0 days 00:00:00
# estatura                               0.076386
# peso                                  11.885267
# imc                                    2.956003
# peito                                  7.439109
# ombro                                  7.642217
# cintura                                6.891228
# quadril                                8.061358
# coxa_d                                 4.338958
# coxa_e                                 5.805383
# perna_d                                4.016024
# perna_e                                4.144523
# ...

# %%
a8.sort_values(by=['data_nascimento'])
# Out:
#     Id                               nome data_nascimento data_avaliacao  \
# 51  52               ALDO SILVA RODRIGUES      1994-12-09     2022-10-01
# 50  51              AUGUSTO MARQUES CUNHA      1996-01-04     2022-10-01
# 48  49           PEDRO HENRIQUE RODRIGUES      1998-04-08     2022-10-01
# 44  45             MATHEUS RODRIGUES LIMA      1999-03-11     2022-10-01
# 47  48          HENRIQUE PEREIRA DA SILVA      1999-06-02     2022-10-01
# 49  50              GUSTAVO MARQUES CUNHA      1999-07-24     2022-10-01
# 46  47              GUILHERME SÁ OLIVEIRA      2000-06-21     2022-10-01
# 43  44              RAMOM TRAJANO DO VALE      2000-10-31     2022-10-01
# 42  43                ANDRÉ WILLIAN SILVA      2000-11-16     2022-10-01
# 52  53                GABRIEL LIMA ARRUDA      2000-11-28     2022-10-01
# 45  46                     LEANDRO TASSIO      2001-03-08     2022-10-01
# 41  42                  GUILHERME MILINKI      2002-01-01     2022-10-01
# ...

# %%
a8['mes'] = a8.data_nascimento.dt.month

# %%
a8['ano'] = a8.data_nascimento.dt.year

# %%
a8.head()
# Out:
#    Id                           nome data_nascimento data_avaliacao  estatura  \
# 0   1  FABIO AUGUSTO PEREIRA QUIRINO      2007-01-23     2022-10-01      1.75
# 1   2                 PEDRO BERNARDO      2008-05-30     2022-10-01      1.56
# 2   3         MATHEUS RAMOS DE SOUSA      2007-06-27     2022-10-01      1.70
# 3   4      ARTHUR ALBUQUERQUE SANTOS      2007-01-14     2022-10-01      1.69
# 4   5         GUILHERME DORO BOTELHO      2007-07-13     2022-10-01      1.56
#
#     peso    imc  peito  ombro  cintura  ...  flexibilidade  vo2max  teste_t  \
# 0  51.05  16.67     77    100      NaN  ...              2     NaN    10.63
# 1  37.70  15.49     74     90      NaN  ...              7    17.5    11.00
# 2  61.75  21.37     86    106      NaN  ...              9     NaN    10.21
# 3  94.85  33.21    106    119      NaN  ...              7     NaN    11.91
# 4  44.65  18.35     74     90      NaN  ...              5     NaN    11.00
#
# ...

# %%
sub15 = a8.query("ano==2008")
sub15.to_csv('sub15.csv', index=False)
sub15
# Out:
#    Id                     nome data_nascimento data_avaliacao  estatura  \
# 1   2           PEDRO BERNARDO      2008-05-30     2022-10-01      1.56
# 6   7              DAVI ROSITO      2008-07-03     2022-10-01      1.70
# 9  10  GUSTAVO HENRIQUE MENDES      2008-03-25     2022-10-01      1.62
#
#     peso    imc  peito  ombro  cintura  ...  flexibilidade  vo2max  teste_t  \
# 1  37.70  15.49     74     90      NaN  ...              7    17.5    11.00
# 6  68.30  23.63     86    101      NaN  ...              0    16.6    10.43
# 9  46.95  17.89     74     92      NaN  ...             14     NaN    10.63
#
#    sprint_20m  adutor_d  adutor_e  posterior_d  posterior_e  mes   ano
# 1        3.37      37.0      52.0          180          180    5  2008
# 6        3.38      38.0      37.0          230          230    7  2008
# 9        3.63      56.0      37.0          180          180    3  2008
#
# [3 rows x 28 columns]

# %%
sub15_media = pd.DataFrame({'media': [sub15.estatura.mean()],
                            'minimo' : [sub15.estatura.min()],
                            'maximo' : [sub15.estatura.max()]}, sub15['nome'])
sub15_media
# Out:
#                             media  minimo  maximo
# nome
# PEDRO BERNARDO           1.626667    1.56     1.7
# DAVI ROSITO              1.626667    1.56     1.7
# GUSTAVO HENRIQUE MENDES  1.626667    1.56     1.7

# %%
sub15_mediana = sub15.median()
sub15_mediana
# Out:
# <ipython-input-31-c7169199056f>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   sub15_mediana = sub15.median()
# <ipython-input-31-c7169199056f>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   sub15_mediana = sub15.median()
# Id                  7.00
# estatura            1.62
# peso               46.95
# imc                17.89
# peito              74.00
# ombro              92.00
# cintura              NaN
# quadril            85.00
# coxa_d             50.00
# coxa_e             46.00
# perna_d            32.00
# perna_e            32.00
# braco_d            23.00
# braco_e            23.00
# impulsividade      30.00
# flexibilidade       7.00
# vo2max             17.05
# teste_t            10.63
# ...

# %%
sub17a = a8.query("ano==2007")
sub17a
# Out:
#     Id                           nome data_nascimento data_avaliacao  \
# 0    1  FABIO AUGUSTO PEREIRA QUIRINO      2007-01-23     2022-10-01
# 2    3         MATHEUS RAMOS DE SOUSA      2007-06-27     2022-10-01
# 3    4      ARTHUR ALBUQUERQUE SANTOS      2007-01-14     2022-10-01
# 4    5         GUILHERME DORO BOTELHO      2007-07-13     2022-10-01
# 5    6         FABIO ANTONIO MENDONÇA      2007-03-19     2022-10-01
# 7    8       KAIO DE OLIVEIRA CARDOSO      2007-08-01     2022-10-01
# 8    9              LEONARDO IGLESIAS      2007-08-28     2022-10-01
# 10  11         KLEBER VINICIUS ROSENO      2007-01-21     2022-10-01
#
#     estatura   peso    imc  peito  ombro  cintura  ...  flexibilidade  vo2max  \
# 0       1.75  51.05  16.67     77    100      NaN  ...              2     NaN
# 2       1.70  61.75  21.37     86    106      NaN  ...              9     NaN
# 3       1.69  94.85  33.21    106    119      NaN  ...              7     NaN
# ...

# %%
sub17b = a8.query("ano==2006")
sub17b
# Out:
#     Id                    nome data_nascimento data_avaliacao  estatura  peso  \
# 17  18  BRENO FERREIRA NICOLAU      2006-09-17     2022-10-01      1.73  61.2
# 20  21            KAUAN CASTRO      2006-04-19     2022-10-01      1.73  62.6
#
#       imc  peito  ombro  cintura  ...  flexibilidade  vo2max  teste_t  \
# 17  20.45     81    101     76.0  ...              9    20.4    10.25
# 20  20.92     84    105     73.0  ...              5     NaN    10.06
#
#     sprint_20m  adutor_d  adutor_e  posterior_d  posterior_e  mes   ano
# 17        3.57      47.0      56.0          210          220    9  2006
# 20        3.25      72.0      48.0          220          210    4  2006
#
# [2 rows x 28 columns]

# %%
sub17 = pd.concat([sub17a, sub17b]).sort_values('data_nascimento')
sub17.to_csv('sub17.csv', index=False)
sub17.head()
# Out:
#     Id                           nome data_nascimento data_avaliacao  \
# 20  21                   KAUAN CASTRO      2006-04-19     2022-10-01
# 17  18         BRENO FERREIRA NICOLAU      2006-09-17     2022-10-01
# 3    4      ARTHUR ALBUQUERQUE SANTOS      2007-01-14     2022-10-01
# 10  11         KLEBER VINICIUS ROSENO      2007-01-21     2022-10-01
# 0    1  FABIO AUGUSTO PEREIRA QUIRINO      2007-01-23     2022-10-01
#
#     estatura   peso    imc  peito  ombro  cintura  ...  flexibilidade  vo2max  \
# 20      1.73  62.60  20.92     84    105     73.0  ...              5     NaN
# 17      1.73  61.20  20.45     81    101     76.0  ...              9    20.4
# 3       1.69  94.85  33.21    106    119      NaN  ...              7     NaN
# 10      1.68  58.50  20.73     80     98      NaN  ...             12     NaN
# 0       1.75  51.05  16.67     77    100      NaN  ...              2     NaN
#
#     teste_t  sprint_20m  adutor_d  adutor_e  posterior_d  posterior_e  mes  \
# ...

# %%
sub20 = a8.query("ano<=2005 & ano>=2003").sort_values('data_nascimento')
sub20.to_excel('sub20.xlsx', index=False)
sub20.head()
# Out:
#     Id                           nome data_nascimento data_avaliacao  \
# 30  31                     ENZO LOPES      2003-02-07     2022-10-01
# 29  30       LEONARDO PEREIRA RIBEIRO      2003-02-07     2022-10-01
# 40  41       RAFAEL HENRIQUE DE CONTI      2003-03-11     2022-10-01
# 23  24      ADRIEL FERREIRA VIRGOLINO      2003-08-09     2022-10-01
# 31  32  ARTHUR HENRIQUE GOMES DE LIMA      2003-09-04     2022-10-01
#
#     estatura   peso    imc  peito  ombro  cintura  ...  flexibilidade  vo2max  \
# 30      1.84  65.35  19.30     86    109     71.0  ...              1    18.1
# 29      1.70  54.80  18.96     83    106     66.0  ...             22    19.6
# 40      1.82  77.15  23.29     95    115     78.0  ...             22    22.4
# 23      1.64  62.10  23.09     86    110     76.0  ...             11     NaN
# 31      1.73  62.10  20.75     89    109     75.0  ...              1    20.3
#
#     teste_t  sprint_20m  adutor_d  adutor_e  posterior_d  posterior_e  mes  \
# ...

# %%
profi = a8.query("ano<=2002").sort_values('data_nascimento')
profi.to_csv('profi.csv', index=False)
profi.head()
# Out:
#     Id                       nome data_nascimento data_avaliacao  estatura  \
# 51  52       ALDO SILVA RODRIGUES      1994-12-09     2022-10-01      1.85
# 50  51      AUGUSTO MARQUES CUNHA      1996-01-04     2022-10-01      1.80
# 48  49   PEDRO HENRIQUE RODRIGUES      1998-04-08     2022-10-01      1.83
# 44  45     MATHEUS RODRIGUES LIMA      1999-03-11     2022-10-01      1.80
# 47  48  HENRIQUE PEREIRA DA SILVA      1999-06-02     2022-10-01      1.83
#
#      peso    imc  peito  ombro  cintura  ...  flexibilidade  vo2max  teste_t  \
# 51  84.40  24.66    100    117     84.0  ...              7    20.5     9.87
# 50  82.55  25.48     97    118     86.0  ...              6    21.7     9.79
# 48  79.80  23.83     95    119     56.0  ...             15    23.7    10.00
# 44  63.80  19.69     89    109     76.0  ...             10    20.2    10.88
# 47  69.85  20.86     89    112     78.0  ...             11    20.4    10.47
#
# ...

# %%
primeiro_tri = a8.query("mes>=1 & mes<=3").sort_values('mes')
primeiro_tri.head()
# Out:
#     Id                           nome data_nascimento data_avaliacao  \
# 0    1  FABIO AUGUSTO PEREIRA QUIRINO      2007-01-23     2022-10-01
# 3    4      ARTHUR ALBUQUERQUE SANTOS      2007-01-14     2022-10-01
# 10  11         KLEBER VINICIUS ROSENO      2007-01-21     2022-10-01
# 41  42              GUILHERME MILINKI      2002-01-01     2022-10-01
# 50  51          AUGUSTO MARQUES CUNHA      1996-01-04     2022-10-01
#
#     estatura   peso    imc  peito  ombro  cintura  ...  flexibilidade  vo2max  \
# 0       1.75  51.05  16.67     77    100      NaN  ...              2     NaN
# 3       1.69  94.85  33.21    106    119      NaN  ...              7     NaN
# 10      1.68  58.50  20.73     80     98      NaN  ...             12     NaN
# 41      1.75  57.75  18.86     82    102     71.0  ...              2    23.4
# 50      1.80  82.55  25.48     97    118     86.0  ...              6    21.7
#
#     teste_t  sprint_20m  adutor_d  adutor_e  posterior_d  posterior_e  mes  \
# ...

# %%
segundo_tri = a8.query("mes>=4 & mes<=6").sort_values('mes')
segundo_tri.head()
# Out:
#     Id                         nome data_nascimento data_avaliacao  estatura  \
# 16  17        VICTOR DA GRAÇA ROCHA      2005-04-12     2022-10-01      1.80
# 20  21                 KAUAN CASTRO      2006-04-19     2022-10-01      1.73
# 27  28  LUCCA DE OLIVEIRA FERNANDES      2004-04-22     2022-10-01      1.74
# 48  49     PEDRO HENRIQUE RODRIGUES      1998-04-08     2022-10-01      1.83
# 1    2               PEDRO BERNARDO      2008-05-30     2022-10-01      1.56
#
#     peso    imc  peito  ombro  cintura  ...  flexibilidade  vo2max  teste_t  \
# 16  75.0  23.15     96    120     80.0  ...              5    19.8     9.50
# 20  62.6  20.92     84    105     73.0  ...              5     NaN    10.06
# 27  69.0  22.79     91    115     76.0  ...             20    20.7     9.81
# 48  79.8  23.83     95    119     56.0  ...             15    23.7    10.00
# 1   37.7  15.49     74     90      NaN  ...              7    17.5    11.00
#
# ...

# %%
terceiro_tri = a8.query("mes>=7 & mes<=9").sort_values('mes')
terceiro_tri.head()
# Out:
#     Id                        nome data_nascimento data_avaliacao  estatura  \
# 4    5      GUILHERME DORO BOTELHO      2007-07-13     2022-10-01      1.56
# 6    7                 DAVI ROSITO      2008-07-03     2022-10-01      1.70
# 12  13  PEDRO HENRIQUE GOMES FARIA      2005-07-15     2022-10-01      1.69
# 15  16          PEDRO REIS MARINHO      2005-07-15     2022-10-01      1.72
# 32  33              RAFAEL MANZINI      2002-07-31     2022-10-01      1.64
#
#      peso    imc  peito  ombro  cintura  ...  flexibilidade  vo2max  teste_t  \
# 4   44.65  18.35     74     90      NaN  ...              5     NaN    11.00
# 6   68.30  23.63     86    101      NaN  ...              0    16.6    10.43
# 12  64.20  22.48     93    100     76.0  ...             13     NaN     9.81
# 15  68.10  23.02     89    109     76.0  ...             17    21.1    10.15
# 32  63.80  23.72     91    100     83.0  ...             10    20.4     9.75
#
# ...

# %%
quarto_tri = a8.query('mes>=10').sort_values('mes')
quarto_tri.head()
# Out:
#     Id                            nome data_nascimento data_avaliacao  \
# 11  12          ANDERSON CAUÃ BALTAZAR      2005-10-06     2022-10-01
# 19  20  GUSTAVO HENRIQUE S. NASCIMENTO      2005-10-18     2022-10-01
# 24  25               GUILHERME CAMARGO      2002-10-24     2022-10-01
# 26  27        SAVIO RAMALHO DOS SANTOS      2002-10-30     2022-10-01
# 28  29            JOÃO VICTOR BERTOLDO      2004-10-11     2022-10-01
#
#     estatura   peso    imc  peito  ombro  cintura  ...  flexibilidade  vo2max  \
# 11      1.68  66.70  23.63     89    112     79.0  ...             21     NaN
# 19      1.75  72.95  23.82     93    112     75.0  ...             10    17.7
# 24      1.74  63.00  20.81     83    106     71.0  ...              7    21.6
# 26      1.81  70.90  21.64     88    108     79.0  ...              4    21.2
# 28      1.73  64.25  21.47     86    101     81.0  ...             11    21.2
#
# ...

# %%
a8.groupby("ano").mean().vo2max
# Out:
# ano
# 1994    20.500000
# 1996    21.700000
# 1998    23.700000
# 1999    20.700000
# 2000    20.500000
# 2001    23.500000
# 2002    21.085714
# 2003    19.120000
# 2004    19.920000
# 2005    19.571429
# 2006    20.400000
# 2007    15.700000
# 2008    17.050000
# Name: vo2max, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,5))
plt.boxplot([primeiro_tri.mes, segundo_tri.mes, terceiro_tri.mes, quarto_tri.mes])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f0bf1c97670>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f0bf1c97c10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f0bf1c97490>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7f0bf1ca51f0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f0bf1ca54c0>,
# ...
#  'means': []}

# %%
plt.boxplot([sub15.peito, sub17.peito, sub20.peito, profi.peito])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f0bf2e9da90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f0bf2eaa070>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f0bf2e9d7c0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7f0bf2eaa610>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f0bf2eaa8e0>,
# ...
#  'means': []}
